# %%
##导入库

import time, sys, smtplib
import pandas as pd
import pyautogui
from PIL import ImageGrab
from PIL import Image

# %%
##测试鼠标位置:pyautogui依据不同电脑屏幕分辨率获取屏幕上（x,y)坐标
print(pyautogui.position())
# Out:
# Point(x=87, y=81)

# %%
pyautogui.click(1913, 282)                 #模拟人工滑动
pyautogui.dragRel(1, 240, duration = 1.1)    #模拟人工滑动
pyautogui.dragRel(0, -240, duration = 1.3) #模拟人工滑动

# %%
time.sleep(1)

for i in range(0, 500):
    dist = 150
    dist2 = 455
    dist3 = 760    

    pyautogui.click(1896, 433)
    pyautogui.dragRel(1, 340, duration=0.5)    
    
    for i in range(0, 8):

        pyautogui.click(1896, 433)
        pyautogui.dragRel(1, 340, duration=0.5)
        time.sleep(1)
        pyautogui.click(677, dist) ##第一栏的数据
        
        time.sleep(1.5)
        
        pyautogui.click(1225, 220) #下载1
        
        time.sleep(0.4) #点击下载图标，猜的过程中等待下
        
        pyautogui.click(1225, 261)
        
        time.sleep(3)
        pyautogui.click(1090, 616)
        time.sleep(0.7)
        pyautogui.click(1707, 991)

        time.sleep(1.5)
        pyautogui.click(87, 80) #回到第一页
        time.sleep(0.5)

        dist += 36.15

    time.sleep(0.5)
    pyautogui.click(87, 80) #回到第一页
## -------------
    for i in range(0, 8):

        time.sleep(1)
        pyautogui.click(677, dist2) ##第一栏的数据
        
        time.sleep(1.5)
        

        pyautogui.click(1225, 220)
        time.sleep(0.4) #点击下载图标，猜的过程中等待下
        pyautogui.click(1225, 261)
        time.sleep(3)
        pyautogui.click(1090, 616)
        time.sleep(0.7)
        pyautogui.click(1707, 991)

        time.sleep(1.5)
        pyautogui.click(104, 80) #回到第一页
        time.sleep(0.5)

        dist2 += 36.15

    time.sleep(0.5)
    pyautogui.click(87, 80) #回到第一页

    for i in range(0, 4):

        time.sleep(1)
        pyautogui.click(677, dist3) ##第一栏的数据
        
        time.sleep(1.5)
        

        pyautogui.click(1225, 220)
        time.sleep(0.4) #点击下载图标，猜的过程中等待下
        pyautogui.click(1225, 261)
        time.sleep(3)
        pyautogui.click(1090, 616)
        time.sleep(0.7)
        pyautogui.click(1707, 991)

        time.sleep(1.5)
        pyautogui.click(104, 80) #回到第一页
        time.sleep(0.5)

        dist3 += 36.15    

    time.sleep(0.5)
    pyautogui.click(87, 80) #回到第一页
##--------------------
    pyautogui.click(1670, 927)#翻页
##--------------------
    time.sleep(0.7)
    pyautogui.click(1896, 433)
    pyautogui.dragRel(1, 140, duration=0.3)

# %%
    for i in range(0, ):

        time.sleep(1)
        pyautogui.click(677, dist3) ##第一栏的数据
        time.sleep(1.2) ##停顿时间依据自己电脑反应速度修改
        pyautogui.click(1225, 220)
        time.sleep(0.2) #点击下载图标，猜的过程中等待下
        pyautogui.click(1225, 261)
        time.sleep(1.1)
        pyautogui.click(1090, 616)
        time.sleep(0.7)
        pyautogui.click(751, 557)

        time.sleep(0.5)
        pyautogui.click(104, 80) #回到第一页
        time.sleep(0.5)

        dist3 += 36.15

# %%
    pyautogui.typewrite(List["代码"][i])
    time.sleep(0.1)
    pyautogui.press('enter')
    time.sleep(0.1)
    pyautogui.press('enter')
    time.sleep(3.2)

    folder_path = List["代码"][i].replace('.','')
    img_name = folder_path + '.png'
    pic = ImageGrab.grab(bbox=(250, 150, 1913, 970))
    pic.save(r'C:\Users\19723\Desktop\截图\1_'+ img_name)
    
    pyautogui.click(1909, 202)
    pyautogui.dragRel(1, 120, duration=0.2)    
    # 输入屏幕左上角和右下角的坐标
    folder_path = List["代码"][i].replace('.','')
    img_name = folder_path + '.png'
    pic = ImageGrab.grab(bbox=(250, 150, 1913, 970))
    pic.save(r'C:\Users\19723\Desktop\截图\2_'+ img_name)

    pyautogui.click(1907, 202)
    pyautogui.dragRel(1, 120, duration=0.2)
    folder_path = List["代码"][i].replace('.','')
    img_name = folder_path + '.png'
    pic = ImageGrab.grab(bbox=(250, 150, 1913, 970))
    pic.save(r'C:\Users\19723\Desktop\截图\3_'+ img_name)
    
    pyautogui.click(1908, 300)
    pyautogui.dragRel(1, 120, duration=0.2)
    folder_path = List["代码"][i].replace('.','')
    img_name = folder_path + '.png'
    pic = ImageGrab.grab(bbox=(250, 150, 1913, 970))
    pic.save(r'C:\Users\19723\Desktop\截图\4_'+ img_name)    
    
    pyautogui.click(1908, 400)
    pyautogui.dragRel(1, 120, duration=0.2)
    folder_path = List["代码"][i].replace('.','')
    img_name = folder_path + '.png'
    pic = ImageGrab.grab(bbox=(250, 150, 1913, 970))
    pic.save(r'C:\Users\19723\Desktop\截图\5_'+ img_name)
    
    pyautogui.click(1908, 550)
    pyautogui.dragRel(1, 120, duration=0.2)
    folder_path = List["代码"][i].replace('.','')
    img_name = folder_path + '.png'
    pic = ImageGrab.grab(bbox=(250, 150, 1913, 970))
    pic.save(r'C:\Users\19723\Desktop\截图\6_'+ img_name)
    
    pyautogui.click(1908, 640)
    pyautogui.dragRel(1, 120, duration=0.2)
    folder_path = List["代码"][i].replace('.','')
    img_name = folder_path + '.png'
    pic = ImageGrab.grab(bbox=(250, 150, 1913, 1000))
    pic.save(r'C:\Users\19723\Desktop\截图\7_'+ img_name)   

    pyautogui.click(1908, 730)
    pyautogui.dragRel(1, 120, duration=0.2)
    folder_path = List["代码"][i].replace('.','')
    img_name = folder_path + '.png'
    pic = ImageGrab.grab(bbox=(250, 150, 1913, 1000))
    pic.save(r'C:\Users\19723\Desktop\截图\8_'+ img_name)   
    
    pyautogui.click(1908, 800)
    pyautogui.dragRel(1, 120, duration=0.2)
    folder_path = List["代码"][i].replace('.','')
    img_name = folder_path + '.png'
    pic = ImageGrab.grab(bbox=(250, 150, 1913, 1000))
    pic.save(r'C:\Users\19723\Desktop\截图\9_'+ img_name)
