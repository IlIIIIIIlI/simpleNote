# %%
##导入模块
import time, sys, smtplib
import pandas as pd
import pyautogui

# %%
##测试鼠标位置:pyautogui依据不同电脑屏幕分辨率获取屏幕上（x,y)坐标
print(pyautogui.position())
# Out:
# Point(x=704, y=494)

# %%
##导入证券代码
List=pd.read_excel(r"C:/Users/19723/Desktop/data1/123221.xlsx")
for i in range(0, len(List)):
    print(List["代码"][i])
# Out:
# 603022.SH
# 600989.SH
# 600242.SH
# 000812.SZ
# 300793.SZ
# 300531.SZ
# 300297.SZ
# 300542.SZ
# 300519.SZ
# 300675.SZ
# 688056.SH
# 000058.SZ
# 300561.SZ
# 603023.SH
# 600343.SH
# 300785.SZ
# 002676.SZ
# 002765.SZ
# 000838.SZ
# 300604.SZ
# 003004.SZ
# 300437.SZ
# 600766.SH
# 600346.SH
# 603042.SH
# 300148.SZ
# 300750.SZ
# 603180.SH
# 002591.SZ
# 600978.SH
# 300724.SZ
# 002590.SZ
# 600825.SH
# 000793.SZ
# 300605.SZ
# 000680.SZ
# 300338.SZ
# 002286.SZ
# 002748.SZ
# 688228.SH
# 605166.SH
# 002922.SZ
# 300076.SZ
# 688379.SH
# 300475.SZ
# 300925.SZ
# 605299.SH
# 002052.SZ
# 000550.SZ
# 300488.SZ
# 603277.SH
# 600767.SH
# 603956.SH
# 300513.SZ
# 300073.SZ
# 002988.SZ
# 688312.SH
# 300654.SZ
# 300409.SZ
# 603588.SH
# 000510.SZ
# 300399.SZ
# 600235.SH
# 000157.SZ
# 603887.SH
# 300761.SZ
# 300329.SZ
# 002836.SZ
# 002319.SZ
# 002206.SZ
# 300500.SZ
# 300062.SZ
# 300447.SZ
# 600132.SH
# 002069.SZ
# 600371.SH
# 603603.SH
# 002472.SZ
# 300755.SZ
# 003017.SZ
# 600768.SH
# 688505.SH
# 605338.SH
# ...

# %%
print(List["名称"][i])
# Out:
# nan

# %%
### 过程实现

for i in range(0, len(List)):
    time.sleep(1)
    pyautogui.click(1703, 1015) ##位置2的坐标，搜索栏
    time.sleep(1.5) ##停顿时间依据自己电脑反应速度修改
    pyautogui.typewrite(List["代码"][i])
    time.sleep(1)
    pyautogui.press('enter')
    pyautogui.press('enter')
    
    time.sleep(1.1)
    pyautogui.click(1767, 116) ##位置3的坐标,excel    
    time.sleep(1.1)
    pyautogui.click(1081, 615) ##保存
    time.sleep(1.1)
    pyautogui.click(755, 559) ##保存
    time.sleep(1.3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-82f7e9924e0e> in <module>
#       1 ### 过程实现
#       2
# ----> 3 for i in range(0, len(List)):
#       4     time.sleep(1)
#       5     pyautogui.click(1703, 1015) ##位置2的坐标，搜索栏
#
# NameError: name 'List' is not defined

# %%
### 过程实现

for i in range(0, len(List)):
    time.sleep(1)
    pyautogui.click(1703, 1015) ##位置2的坐标，搜索栏
    time.sleep(1.5) ##停顿时间依据自己电脑反应速度修改
    pyautogui.typewrite(List["代码"][i])
    time.sleep(1)
    pyautogui.press('enter')
    pyautogui.press('enter')
    time.sleep(1)
    pyautogui.click(1767, 116) ##位置3的坐标,excel
    time.sleep(1.5)
    l1=List["代码"][i].replace('.','')
    pyautogui.typewrite(l1)
    time.sleep(1)
    pyautogui.press('enter')
    pyautogui.press('enter')
    time.sleep(1)
    pyautogui.press('ESC') 
    pyautogui.press('ESC') ##由于Wind中下载的excel会自动打开，因而需利用Alt+F4快捷键将其关闭
